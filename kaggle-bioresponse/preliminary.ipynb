# %%
import pandas as pd
import numpy as np
data = pd.read_csv('data/train.csv')

# %%
data.describe()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Activity</th>
#       <th>D1</th>
#       <th>D2</th>
#       <th>D3</th>
#       <th>D4</th>
#       <th>D5</th>
#       <th>D6</th>
#       <th>D7</th>
#       <th>D8</th>
#       <th>D9</th>
#       <th>...</th>
#       <th>D1767</th>
#       <th>D1768</th>
#       <th>D1769</th>
#       <th>D1770</th>
#       <th>D1771</th>
#       <th>D1772</th>
#       <th>D1773</th>
#       <th>D1774</th>
#       <th>D1775</th>
#       <th>D1776</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>3751.000000</td>
#       <td>3751.000000</td>
#       <td>3751.000000</td>
#       <td>3751.000000</td>
#       <td>3751.000000</td>
#       <td>3751.000000</td>
#       <td>3751.000000</td>
#       <td>3751.000000</td>
#       <td>3751.000000</td>
#       <td>3751.000000</td>
#       <td>...</td>
#       <td>3751.000000</td>
# ...
